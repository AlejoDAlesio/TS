# %% [markdown]
# <img src="logo-UNSAM.png" style="float: right;" width="300" alt="Logo">

# %% [markdown]
# # <center>Análisis y Procesamiento de Señales</center>
# <hr>
#
# ## <center>**TS4**: "Primeras nociones de estimación espectral"</center>
#
# <br><br>
#
# ### <center>1er Cuatrimestre - 2026</center>
# ### <center>**Alumno:** D'Alesio Alejo</center>
#
#
# <br>

# %% [markdown]
# Inicialmente creamos una señal senoidal con ruido, que tendrá la seguiente forma:

# %% [markdown]
# \begin{align}
#     x(k) &= a_0 \cdot \sin(\Omega_1 \cdot n) + n_a(n) \\[6pt]
#     a_0 &= \sqrt{2} \\[6pt]
#     \Omega_1 &= \Omega_0 + f_r \cdot \frac{2\pi}{N} \\[6pt]
#     \Omega_0 &= \frac{\pi}{2}
# \end{align}
#
#  donde $f_r$ es una variable aleatoria con distribución de probabilidad:
#
# \begin{align}
#     f_r &\sim \mathcal{U}(-2,\, 2) \\[6pt]
#     n_a &\sim \mathcal{N}(0,\, \sigma^2)
# \end{align}

# %% [markdown]
# Considero una cantidad de 200 realizaciones (muestras tomadas de $f_r$) de 1000 muestras para cada experimento. Para el caso del ruido, tengo en cuenta la potencia de ruido como $P_r = \frac{P_s}{10^{\frac{SNR_{dB}}{10}}}$

# %% [markdown]
# Debido a que trabajamos con registros de longitud finita ($N=1000$), la señal se ve afectada por el truncamiento temporal. Para mitigar los efectos del spectral leakage y mejorar la precisión de las estimaciones, aplicamos un proceso de ventaneo. Matemáticamente, esto consiste en multiplicar la señal en el tiempo por una función de ventana $w[n]$, lo que equivale a una convolución en el dominio de la frecuencia entre el espectro de la señal y la transformada de la ventana. En este trabajo, comparamos cuatro funciones de ventana: Rectangular, Flat-top, Blackman-Harris y Hamming. Para cada una, se implementaron dos estimadores estadísticos:
# * **Estimador de Amplitud ($\hat{a}_0$):** Calculado a partir del módulo de la FFT en la frecuencia de interés ($\Omega_0$).
#     $$\hat{a}_0 = |X_w^i(\Omega_0)|$$
# <br>
#
# * **Estimador de Frecuencia ($\hat{\Omega}_1$):** Obtenido mediante la búsqueda del máximo valor (*argmax*) en el espectro de magnitud.
#     $$\hat{\Omega}_1^i = \arg \max_f \{ |X_w^i(\Omega)| \}$$
# <br>

# %% [markdown]
# Para evaluar el desempeño de cada ventana frente al ruido y al desplazamiento de frecuencia, calculamos el sesgo ($s_a$) y la varianza ($v_a$) de los estimadores. El objetivo es determinar qué ventana ofrece el mejor compromiso entre resolución espectral y exactitud en la medición de amplitud.

# %% [markdown]
# * **Sesgo del Estimador ($s_a$):** Representa la exactitud del estimador. Es la diferencia entre el valor esperado (promedio) de nuestras estimaciones y el valor real del parámetro $a_0$.
#     $$s_a = E\{\hat{a}_0\} - a_0$$
# <br>
#
# * **Varianza del Estimador ($v_a$):** Mide la precisión o dispersión de los resultados. Indica qué tan sensible es el estimador al ruido en cada una de las realizaciones.
#     $$v_a = var\{\hat{a}_0\} = E\{(\hat{a}_0 - E\{\hat{a}_0\})^2\}$$
# <br>

# %% [markdown]
# ## Caso de Señal con SNR 10 dB

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal.windows import flattop
from scipy.signal.windows import blackmanharris
from scipy.signal.windows import hamming

#DECLARACION DE VARIABLES 

N = 1000 #Cantidad de muestras (filas)
R = 200 #cantidad de realizaciones (Columna)
w0 = N/4 #frecuencia de w0 en mitad de nyquist
a0 = np.sqrt(2) #amplitud, elijo raiz(2) para normalizarla
Ps = 1
mu = 0
SNR_dB = 10  # es el SNR deseado, ej 10
Pr = Ps / (10**(SNR_dB/10)) #potencia del ruido 

#genero una lista de valores random de -2 a 2

fr = np.random.uniform(low=-2, high=2,size =  200) 

#genero el vector de n de 1000 elementos

n = np.arange(N) #Genero de un array de muestras con una cantidad de N-1 muestras
array_n = n.reshape(N,1)
#frecuencia

w = (2 * np.pi/N) * (w0 + fr)
 
#%% CREO SENO CON RUIDO

SNR_dB = 10  # es el SNR deseado, ej 10
Pr = Ps / (10**(SNR_dB/10)) #potencia del ruido 

#ruido
sigma = np.sqrt(Pr) #es la que uso en ruido, sigma² es potencia de ruido
ruido = np.random.normal(mu, sigma, size = (N,R))

#Funcion seno

x_n= a0*np.sin((w*array_n)) 

#Le sumo el ruido

x_r =  x_n + ruido

plt.figure()
plt.plot(x_r);         
plt.title("Señal senoidal con SNR 10 dB")
plt.xlabel("Muestras (n)")
plt.ylabel("Amplitud")
plt.show()

# %% [markdown]
# ### Análisis de Estimadores a SNR 10 dB

# %%
#%% -------------- VENTANEO ------------------
XXr = np.fft.fft(x_r,n=N, axis = 0)
#RECTANGULAR


#Estimador de Energia

#Sesgo

# 1. Identificamos el bin exacto de nuestra frecuencia fundamental w0
bin_w0 = int(N/4) # Esto da 250, sino daria 250.0


# 2. Extraemos el valor complejo de la FFT en ese bin para las 200 realizaciones
# XXr tiene forma (1000, 200), así que tomamos la fila 250 y todas las columnas (:)
X_w0 = XXr[bin_w0, :]  #el resultado es una vector de 200 numeros

#cada elemento de X_w0 es la FFT de en w0 de cada experimento

# 3. Calculamos la amplitud estimada para cada una de las 200 realizaciones

a_r_estimado = (np.abs(X_w0) * 2) / N #multiplico por 2 para recuperar la energia dividida en dos mitades
                                    # divido por N para escalar bien
# 4. Calculamos el valor esperado (promedio de las 200 estimaciones)
E_a = np.mean(a_r_estimado)

# 5. Calculamos el sesgo
sesgo = E_a - a0


#Varianza

varianza_a = np.var(a_r_estimado)


#Estimador de Frecuencia

# Sesgo

# 1. Nos quedamos con la magnitud de la mitad positiva del espectro (Nyquist)
# para asegurarnos de no agarrar el pico de las frecuencias negativas por error.
magnitud_espectro = np.abs(XXr[:N//2 + 1, :])

# 2. Encontramos el índice (el bin 'k') donde está el máximo de energía
# np.argmax te devuelve la posición del valor más grande. 
# axis=0 lo hace para cada una de las 200 columnas (realizaciones) a la vez.
f_r_estimado = np.argmax(magnitud_espectro, axis=0)
# k_estimado es ahora un vector de 200 números (ej: [249, 251, 250, 248...])

# 3. Calculamos el valor esperado (promedio de los 200 índices estimados)
E_f_r = np.mean(f_r_estimado)

# 4. Calculamos el sesgo (Diferencia entre el promedio estimado y la frecuencia real w0)
sesgo_f_r = E_f_r - w0

# Varianza
varianza_f_r = np.var(f_r_estimado)

#FLATTOP

# Generamos la ventana de tamaño N (1000 muestras)
# sym=True es el comportamiento por defecto.

ventana_ft = flattop(N, sym=True)

# La ventana es un array 1D de (1000,). Para multiplicarla por la matriz x_r 
# que es de (1000, 200), necesitamos darle forma de columna (1000, 1)
ventana_ft_col = ventana_ft.reshape(N, 1)

# Aplicamos el ventaneo multiplicando la señal por la ventana en el tiempo
x_r_ft = x_r * ventana_ft_col

# Calculamos la nueva FFT sobre la señal ventaneada
XXr_ft = np.fft.fft(x_r_ft, n=N, axis=0)

# ---  ESTIMADOR DE AMPLITUD (CON FLAT TOP) ---

#sesgo

# Extraemos el bin de interés
X_w0_ft = XXr_ft[bin_w0, :]


a_estimado_ft = (np.abs(X_w0_ft) * 2) / N #Lo dividimos por la suma de los valores de la ventana

E_a_ft = np.mean(a_estimado_ft)
sesgo_a_ft = E_a_ft - a0

#varianza
varianza_a_ft = np.var(a_estimado_ft)

# ---  ESTIMADOR DE FRECUENCIA (CON FLAT TOP) ---

#sesgo

magnitud_espectro_ft = np.abs(XXr_ft[:N//2 + 1, :])
f_estimado_ft = np.argmax(magnitud_espectro_ft, axis=0)


E_k_ft = np.mean(f_estimado_ft)
sesgo_k_ft = E_k_ft - w0

#varianza

varianza_k_ft = np.var(f_estimado_ft)


#BLACHMANHARRIS


# Generamos la ventana de tamaño N (1000 muestras)
ventana_bh = blackmanharris(N, sym=True)

# La transformamos en columna para multiplicarla por la matriz de 200 realizaciones
ventana_bh_col = ventana_bh.reshape(N, 1)

# Aplicamos la ventana a la señal en el tiempo
x_r_bh = x_r * ventana_bh_col

# Calculamos la FFT de la señal ventaneada
XXr_bh = np.fft.fft(x_r_bh, n=N, axis=0)

# --- 2. ESTIMADOR DE AMPLITUD (CON BLACKMAN-HARRIS) ---

# Extraemos el bin exacto de w0 (250)

#sesgo

X_w0_bh = XXr_bh[bin_w0, :]


a_estimado_bh = (np.abs(X_w0_bh) * 2) / N


E_a_bh = np.mean(a_estimado_bh)
sesgo_a_bh = E_a_bh - a0

#varianza

varianza_a_bh = np.var(a_estimado_bh)

# --- 3. ESTIMADOR DE FRECUENCIA (CON BLACKMAN-HARRIS) ---

# Nos quedamos con la mitad del espectro
magnitud_espectro_bh = np.abs(XXr_bh[:N//2 + 1, :])

# Buscamos el bin con mayor energía
f_estimado_bh = np.argmax(magnitud_espectro_bh, axis=0)


E_k_bh = np.mean(f_estimado_bh)
sesgo_k_bh = E_k_bh - w0

#varianza

varianza_k_bh = np.var(f_estimado_bh)

#HAMMING

# Generamos la ventana de tamaño N (1000 muestras)
# M=N, sym=True es el comportamiento por defecto
ventana_hm = hamming(N, sym=True)

# La transformamos en columna
ventana_hm_col = ventana_hm.reshape(N, 1)

# Aplicamos la ventana a la señal en el tiempo
x_r_hm = x_r * ventana_hm_col

# Calculamos la FFT de la señal ventaneada
XXr_hm = np.fft.fft(x_r_hm, n=N, axis=0)


# --- 2. ESTIMADOR DE AMPLITUD (CON HAMMING) ---

#sesgo

# Extraemos el bin exacto de w0 (250)
X_w0_hm = XXr_hm[bin_w0, :]


a_estimado_hm = (np.abs(X_w0_hm) * 2) / N


E_a_hm = np.mean(a_estimado_hm)
sesgo_a_hm = E_a_hm - a0

#varianza

varianza_a_hm = np.var(a_estimado_hm)

# --- 3. ESTIMADOR DE FRECUENCIA (CON HAMMING) ---

#sesgo

# Nos quedamos con la mitad del espectro
magnitud_espectro_hm = np.abs(XXr_hm[:N//2 + 1, :])

# Buscamos el bin con mayor energía
f_estimado_hm = np.argmax(magnitud_espectro_hm, axis=0)

# Cálculos estadísticos
E_f_hm = np.mean(f_estimado_hm)
sesgo_f_hm = E_f_hm - w0

#varianza
varianza_f_hm = np.var(f_estimado_hm)


# ── Datos Amplitud ──────────────────────────────────────────────────────────
datos_amplitud = [
    ["Rectangular", f"{sesgo:.6f}",       f"{varianza_a:.6f}"],
    ["Flat-top",    f"{sesgo_a_ft:.6f}",  f"{varianza_a_ft:.6f}"],
    ["Blackman",    f"{sesgo_a_bh:.6f}",  f"{varianza_a_bh:.6f}"],
    ["Hamming",     f"{sesgo_a_hm:.6f}",  f"{varianza_a_hm:.6f}"],
]

# ── Datos Frecuencia ────────────────────────────────────────────────────────
datos_frecuencia = [
    ["Rectangular", f"{sesgo_f_r:.6f}",  f"{varianza_f_r:.6f}"],
    ["Flat-top",    f"{sesgo_k_ft:.6f}", f"{varianza_k_ft:.6f}"],
    ["Blackman",    f"{sesgo_k_bh:.6f}", f"{varianza_k_bh:.6f}"],
    ["Hamming",     f"{sesgo_f_hm:.6f}", f"{varianza_f_hm:.6f}"],
]

# ── Figura ──────────────────────────────────────────────────────────────────
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 5))

for ax in (ax1, ax2):
    ax.axis("off")

col_labels1 = ["", r"$s_a$", r"$v_a$"]

# Tabla Amplitud
ax1.set_title("Estimación de Amplitud a 10 dB", fontweight="bold", loc="left", pad=8)
tabla1 = ax1.table(
    cellText=datos_amplitud,
    colLabels=col_labels1,
    loc="center",
    cellLoc="center",
)
tabla1.auto_set_font_size(False)
tabla1.set_fontsize(10)
tabla1.scale(1.4, 1.6)

col_labels2 = ["", r"$s_f$", r"$v_f$"]
# Tabla Frecuencia
ax2.set_title("Estimación de Frecuencia a 10 dB", fontweight="bold", loc="left", pad=8)
tabla2 = ax2.table(
    cellText=datos_frecuencia,
    colLabels=col_labels2,
    loc="center",
    cellLoc="center",
)
tabla2.auto_set_font_size(False)
tabla2.set_fontsize(10)
tabla2.scale(1.4, 1.6)

plt.tight_layout()
plt.show();

# %% [markdown]
# En primera instancia, se observa en la tabla de la estimación de la amplitud, que  en los casos del Sesgo Determinístico ($s_a$) todas las ventanas presentan un sesgo negativo significativo. Esto no es un error de medición, sino una consecuencia de la pérdida de ganancia coherente propia de cada ventana (en cada ventana estoy normalizando por $1/N$). La ventana Flat-top presenta el mayor sesgo ($\approx -1.13$) debido a que su estructura en el tiempo atenúa más energía que la Rectangular. Para el caso de la Varianza ($v_a$), a pesar de su sesgo, la Flat-top demuestra ser el estimador más preciso con una varianza casi nula ($0.00096$), aunque la frecuencia de la señal varíe aleatoriamente entre bins, la amplitud reportada se mantiene constante. Por el contrario, la ventana Rectangular presenta la mayor varianza ($0.23$), evidenciando su incapacidad para dar una lectura estable si la señal no está perfectamente centrada en un bin.

# %% [markdown]
# Para el caso de la tabla de la estimacion de frecuencia, la varianza de frecuencia ($v_f \approx 1.34$) es prácticamente idéntica en todos los casos. Esto ocurre porque la varianza está dominada por el desplazamiento aleatorio introducido en la señal de entrada ($\text{fr} \in [-2, 2]$) y por la resolución discreta de la FFT.

# %% [markdown]
# ## Caso de Señal con SNR 3 dB

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal.windows import flattop
from scipy.signal.windows import blackmanharris
from scipy.signal.windows import hamming

#DECLARACION DE VARIABLES 

N = 1000 #Cantidad de muestras (filas)
R = 200 #cantidad de realizaciones (Columna)
w0 = N/4 #frecuencia de w0 en mitad de nyquist
a0 = np.sqrt(2) #amplitud, elijo raiz(2) para normalizarla
Ps = 1
mu = 0
SNR_dB = 3  # es el SNR deseado
Pr = Ps / (10**(SNR_dB/10)) #potencia del ruido 

#genero una lista de valores random de -2 a 2

fr = np.random.uniform(low=-2, high=2,size =  200) 

#genero el vector de n de 1000 elementos

n = np.arange(N) #Genero de un array de muestras con una cantidad de N-1 muestras
array_n = n.reshape(N,1)
#frecuencia

w = (2 * np.pi/N) * (w0 + fr)
 
#%% CREO SENO CON RUIDO

SNR_dB = 10  # es el SNR deseado, ej 10
Pr = Ps / (10**(SNR_dB/10)) #potencia del ruido 

#ruido
sigma = np.sqrt(Pr) #es la que uso en ruido, sigma² es potencia de ruido
ruido = np.random.normal(mu, sigma, size = (N,R))

#Funcion seno

x_n= a0*np.sin((w*array_n)) 

#Le sumo el ruido

x_r =  x_n + ruido

plt.figure()
plt.plot(x_r);         
plt.title("Señal senoidal con SNR 3 dB")
plt.xlabel("Muestras (n)")
plt.ylabel("Amplitud")
plt.show()

# %% [markdown]
# ### Análisis de Estimadores a SNR 3 dB

# %%
#%% -------------- VENTANEO ------------------
XXr = np.fft.fft(x_r,n=N, axis = 0)
#RECTANGULAR


#Estimador de Energia

#Sesgo

# 1. Identificamos el bin exacto de nuestra frecuencia fundamental w0
bin_w0 = int(N/4) # Esto da 250, sino daria 250.0


# 2. Extraemos el valor complejo de la FFT en ese bin para las 200 realizaciones
# XXr tiene forma (1000, 200), así que tomamos la fila 250 y todas las columnas (:)
X_w0 = XXr[bin_w0, :]  #el resultado es una vector de 200 numeros

#cada elemento de X_w0 es la FFT de en w0 de cada experimento

# 3. Calculamos la amplitud estimada para cada una de las 200 realizaciones

a_r_estimado = (np.abs(X_w0) * 2) / N #multiplico por 2 para recuperar la energia dividida en dos mitades
                                    # divido por N para escalar bien
# 4. Calculamos el valor esperado (promedio de las 200 estimaciones)
E_a = np.mean(a_r_estimado)

# 5. Calculamos el sesgo
sesgo = E_a - a0


#Varianza

varianza_a = np.var(a_r_estimado)


#Estimador de Frecuencia

# Sesgo

# 1. Nos quedamos con la magnitud de la mitad positiva del espectro (Nyquist)
# para asegurarnos de no agarrar el pico de las frecuencias negativas por error.
magnitud_espectro = np.abs(XXr[:N//2 + 1, :])

# 2. Encontramos el índice (el bin 'k') donde está el máximo de energía
# np.argmax te devuelve la posición del valor más grande. 
# axis=0 lo hace para cada una de las 200 columnas (realizaciones) a la vez.
f_r_estimado = np.argmax(magnitud_espectro, axis=0)
# k_estimado es ahora un vector de 200 números (ej: [249, 251, 250, 248...])

# 3. Calculamos el valor esperado (promedio de los 200 índices estimados)
E_f_r = np.mean(f_r_estimado)

# 4. Calculamos el sesgo (Diferencia entre el promedio estimado y la frecuencia real w0)
sesgo_f_r = E_f_r - w0

# Varianza
varianza_f_r = np.var(f_r_estimado)

#FLATTOP

# Generamos la ventana de tamaño N (1000 muestras)
# sym=True es el comportamiento por defecto.

ventana_ft = flattop(N, sym=True)

# La ventana es un array 1D de (1000,). Para multiplicarla por la matriz x_r 
# que es de (1000, 200), necesitamos darle forma de columna (1000, 1)
ventana_ft_col = ventana_ft.reshape(N, 1)

# Aplicamos el ventaneo multiplicando la señal por la ventana en el tiempo
x_r_ft = x_r * ventana_ft_col

# Calculamos la nueva FFT sobre la señal ventaneada
XXr_ft = np.fft.fft(x_r_ft, n=N, axis=0)

# ---  ESTIMADOR DE AMPLITUD (CON FLAT TOP) ---

#sesgo

# Extraemos el bin de interés
X_w0_ft = XXr_ft[bin_w0, :]

# Reemplazamos "N" por la suma de la ventana para compensar la atenuación

a_estimado_ft = (np.abs(X_w0_ft) * 2) / N #Lo dividimos por la suma de los valores de la ventana

E_a_ft = np.mean(a_estimado_ft)
sesgo_a_ft = E_a_ft - a0

#varianza
varianza_a_ft = np.var(a_estimado_ft)

# ---  ESTIMADOR DE FRECUENCIA (CON FLAT TOP) ---

#sesgo

magnitud_espectro_ft = np.abs(XXr_ft[:N//2 + 1, :])
f_estimado_ft = np.argmax(magnitud_espectro_ft, axis=0)


E_k_ft = np.mean(f_estimado_ft)
sesgo_k_ft = E_k_ft - w0

#varianza

varianza_k_ft = np.var(f_estimado_ft)


#BLACHMANHARRIS


# Generamos la ventana de tamaño N (1000 muestras)
ventana_bh = blackmanharris(N, sym=True)

# La transformamos en columna para multiplicarla por la matriz de 200 realizaciones
ventana_bh_col = ventana_bh.reshape(N, 1)

# Aplicamos la ventana a la señal en el tiempo
x_r_bh = x_r * ventana_bh_col

# Calculamos la FFT de la señal ventaneada
XXr_bh = np.fft.fft(x_r_bh, n=N, axis=0)

# --- 2. ESTIMADOR DE AMPLITUD (CON BLACKMAN-HARRIS) ---

# Extraemos el bin exacto de w0 (250)

#sesgo

X_w0_bh = XXr_bh[bin_w0, :]

# Escalamos usando la suma de los valores de la ventana Blackman-Harris

a_estimado_bh = (np.abs(X_w0_bh) * 2) / N


E_a_bh = np.mean(a_estimado_bh)
sesgo_a_bh = E_a_bh - a0

#varianza

varianza_a_bh = np.var(a_estimado_bh)

# --- 3. ESTIMADOR DE FRECUENCIA (CON BLACKMAN-HARRIS) ---

# Nos quedamos con la mitad del espectro
magnitud_espectro_bh = np.abs(XXr_bh[:N//2 + 1, :])

# Buscamos el bin con mayor energía
f_estimado_bh = np.argmax(magnitud_espectro_bh, axis=0)


E_k_bh = np.mean(f_estimado_bh)
sesgo_k_bh = E_k_bh - w0

#varianza

varianza_k_bh = np.var(f_estimado_bh)

#HAMMING

# Generamos la ventana de tamaño N (1000 muestras)
# M=N, sym=True es el comportamiento por defecto
ventana_hm = hamming(N, sym=True)

# La transformamos en columna
ventana_hm_col = ventana_hm.reshape(N, 1)

# Aplicamos la ventana a la señal en el tiempo
x_r_hm = x_r * ventana_hm_col

# Calculamos la FFT de la señal ventaneada
XXr_hm = np.fft.fft(x_r_hm, n=N, axis=0)


# --- 2. ESTIMADOR DE AMPLITUD (CON HAMMING) ---

#sesgo

# Extraemos el bin exacto de w0 (250)
X_w0_hm = XXr_hm[bin_w0, :]

# Escalamos usando la suma de los valores de la ventana Hamming

a_estimado_hm = (np.abs(X_w0_hm) * 2) / N


E_a_hm = np.mean(a_estimado_hm)
sesgo_a_hm = E_a_hm - a0

#varianza

varianza_a_hm = np.var(a_estimado_hm)

# --- 3. ESTIMADOR DE FRECUENCIA (CON HAMMING) ---

#sesgo

# Nos quedamos con la mitad del espectro
magnitud_espectro_hm = np.abs(XXr_hm[:N//2 + 1, :])

# Buscamos el bin con mayor energía
f_estimado_hm = np.argmax(magnitud_espectro_hm, axis=0)

# Cálculos estadísticos
E_f_hm = np.mean(f_estimado_hm)
sesgo_f_hm = E_f_hm - w0

#varianza
varianza_f_hm = np.var(f_estimado_hm)


# ── Datos Amplitud ──────────────────────────────────────────────────────────
datos_amplitud = [
    ["Rectangular", f"{sesgo:.6f}",       f"{varianza_a:.6f}"],
    ["Flat-top",    f"{sesgo_a_ft:.6f}",  f"{varianza_a_ft:.6f}"],
    ["Blackman",    f"{sesgo_a_bh:.6f}",  f"{varianza_a_bh:.6f}"],
    ["Hamming",     f"{sesgo_a_hm:.6f}",  f"{varianza_a_hm:.6f}"],
]

# ── Datos Frecuencia ────────────────────────────────────────────────────────
datos_frecuencia = [
    ["Rectangular", f"{sesgo_f_r:.6f}",  f"{varianza_f_r:.6f}"],
    ["Flat-top",    f"{sesgo_k_ft:.6f}", f"{varianza_k_ft:.6f}"],
    ["Blackman",    f"{sesgo_k_bh:.6f}", f"{varianza_k_bh:.6f}"],
    ["Hamming",     f"{sesgo_f_hm:.6f}", f"{varianza_f_hm:.6f}"],
]

# ── Figura ──────────────────────────────────────────────────────────────────
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 5))

for ax in (ax1, ax2):
    ax.axis("off")

col_labels1 = ["", r"$s_a$", r"$v_a$"]

# Tabla Amplitud
ax1.set_title("Estimación de Amplitud a 3 dB", fontweight="bold", loc="left", pad=8)
tabla1 = ax1.table(
    cellText=datos_amplitud,
    colLabels=col_labels1,
    loc="center",
    cellLoc="center",
)
tabla1.auto_set_font_size(False)
tabla1.set_fontsize(10)
tabla1.scale(1.4, 1.6)

col_labels2 = ["", r"$s_f$", r"$v_f$"]
# Tabla Frecuencia
ax2.set_title("Estimación de Frecuencia a 3 dB", fontweight="bold", loc="left", pad=8)
tabla2 = ax2.table(
    cellText=datos_frecuencia,
    colLabels=col_labels2,
    loc="center",
    cellLoc="center",
)
tabla2.auto_set_font_size(False)
tabla2.set_fontsize(10)
tabla2.scale(1.4, 1.6)

plt.tight_layout()
plt.show();

# %% [markdown]
# Ahora estamos en un caso de un ruido de 3 dB, si observamos la tabla del estimador de amplitud, vemos que los valores de sesgo se mantienen casi idénticos a los de 10 dB. Esto confirma que el sesgo es determinístico, es decir, no ocurre por azar sino que es una consecuencia directa, predecible y depende de la geometría de la ventana (pérdida de ganancia coherente) y no de la cantidad de ruido. La Flat-top sigue teniendo el sesgo más alto ($\approx -1.13$) por su fuerte atenuación temporal. Con respecto a la varianza ($v_a$) se observa un ligero incremento en la varianza en todas las ventanas respecto al caso de 10 dB. Sin embargo, la Flat-top sigue manteniendo una varianza mínima ($0.001$). La ventana Rectangular continúa siendo la menos fiable para medir amplitud ($0.21$). Luego, en la tabla de la estimación de frecuencia, vemos que el sesgo de Frecuencia ($s_f$), a diferencia del caso de 10 dB donde el sesgo era despreciable ($\approx 0.05$), a 3 dB el sesgo ha aumentado notablemente a valores cercanos a -0.19. Esto indica que el ruido es lo suficientemente fuerte como para dificultar la detección del máximo exacto. Con respecto a la varianza de frecuencia ($v_f$), se observa que ha subido (de $\approx 1.34$ a valores entre 1.44 y 1.58). El ruido está provocando que, en algunas realizaciones, el valor máximo de la FFT se encuentre en un bin incorrecto debido a picos de ruido aleatorios, aumentando la incertidumbre del estimador.

# %% [markdown]
# ## Bonus 1)

# %% [markdown]
# En este apartado voy a realizar los histogramas de los estimadores tanto para 3 dB como para 10 dB. Se van a observar dos gráficos, uno con los histogramas de cada ventana separada y otro grafico con todos los histogramas juntos.

# %% [markdown]
# ### Histogramas de estimadores a 10 dB

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal.windows import flattop
from scipy.signal.windows import blackmanharris
from scipy.signal.windows import hamming

#DECLARACION DE VARIABLES 

N = 1000 #Cantidad de muestras (filas)
R = 200 #cantidad de realizaciones (Columna)
w0 = N/4 #frecuencia de w0 en mitad de nyquist
a0 = np.sqrt(2) #amplitud, elijo raiz(2) para normalizarla
Ps = 1
mu = 0
SNR_dB = 10  # es el SNR deseado, ej 10
Pr = Ps / (10**(SNR_dB/10)) #potencia del ruido 

#genero una lista de valores random de -2 a 2

fr = np.random.uniform(low=-2, high=2,size =  200) 

#genero el vector de n de 1000 elementos

n = np.arange(N) #Genero de un array de muestras con una cantidad de N-1 muestras
array_n = n.reshape(N,1)
#frecuencia

w = (2 * np.pi/N) * (w0 + fr)
 
#%% CREO SENO CON RUIDO

SNR_dB = 10  # es el SNR deseado, ej 10
Pr = Ps / (10**(SNR_dB/10)) #potencia del ruido 

#ruido
sigma = np.sqrt(Pr) #es la que uso en ruido, sigma² es potencia de ruido
ruido = np.random.normal(mu, sigma, size = (N,R))

#Funcion seno

x_n= a0*np.sin((w*array_n)) 

#Le sumo el ruido

x_r =  x_n + ruido

#PSD y graficos
XXr = np.fft.fft(x_r,n=N, axis = 0)
#%% -------------- VENTANEO ------------------

#RECTANGULAR

#Estimador de Energia

#Sesgo

# 1. Identificamos el bin exacto de nuestra frecuencia fundamental w0
bin_w0 = int(N/4) # Esto da 250, sino daria 250.0

# 2. Extraemos el valor complejo de la FFT en ese bin para las 200 realizaciones
# XXr tiene forma (1000, 200), así que tomamos la fila 250 y todas las columnas (:)
X_w0 = XXr[bin_w0, :]  #el resultado es una vector de 200 numeros

#cada elemento de X_w0 es la FFT de en w0 de cada experimento

# 3. Calculamos la amplitud estimada para cada una de las 200 realizaciones

a_r_estimado = (np.abs(X_w0) * 2) / N #multiplico por 2 para recuperar la energia dividida en dos mitades
                                    # divido por N para escalar bien
# 4. Calculamos el valor esperado (promedio de las 200 estimaciones)
E_a = np.mean(a_r_estimado)

# 5. Calculamos el sesgo
sesgo = E_a - a0

#Varianza

varianza_a = np.var(a_r_estimado)


#Estimador de Frecuencia

# Sesgo

# 1. Nos quedamos con la magnitud de la mitad positiva del espectro (Nyquist)
# para asegurarnos de no agarrar el pico de las frecuencias negativas por error.
magnitud_espectro = np.abs(XXr[:N//2 + 1, :])

# 2. Encontramos el índice (el bin 'k') donde está el máximo de energía
f_r_estimado = np.argmax(magnitud_espectro, axis=0)
# k_estimado es ahora un vector de 200 números (ej: [249, 251, 250, 248...])

# 3. Calculamos el valor esperado (promedio de los 200 índices estimados)
E_f_r = np.mean(f_r_estimado)

# 4. Calculamos el sesgo (Diferencia entre el promedio estimado y la frecuencia real w0)
sesgo_f_r = E_f_r - w0

# Varianza
varianza_f_r = np.var(f_r_estimado)

#FLATTOP
ventana_ft = flattop(N, sym=True)

ventana_ft_col = ventana_ft.reshape(N, 1)

# Aplicamos el ventaneo multiplicando la señal por la ventana en el tiempo
x_r_ft = x_r * ventana_ft_col

# Calculamos la nueva FFT sobre la señal ventaneada
XXr_ft = np.fft.fft(x_r_ft, n=N, axis=0)


# ---  ESTIMADOR DE AMPLITUD (CON FLAT TOP) ---

#sesgo

# Extraemos el bin de interés
X_w0_ft = XXr_ft[bin_w0, :]

a_estimado_ft = (np.abs(X_w0_ft)*2) / N

#a_estimado_ft = (np.abs(X_w0_ft)) / N #Lo dividimos por la suma de los valores de la ventana

E_a_ft = np.mean(a_estimado_ft)
sesgo_a_ft = E_a_ft - a0

#varianza
varianza_a_ft = np.var(a_estimado_ft)

# ---  ESTIMADOR DE FRECUENCIA (CON FLAT TOP) ---

#sesgo

magnitud_espectro_ft = np.abs(XXr_ft[:N//2 + 1, :])
f_estimado_ft = np.argmax(magnitud_espectro_ft, axis=0)


E_k_ft = np.mean(f_estimado_ft)
sesgo_k_ft = E_k_ft - w0

#varianza

varianza_k_ft = np.var(f_estimado_ft)

#BLACHMANHARRIS


# Generamos la ventana de tamaño N (1000 muestras)
ventana_bh = blackmanharris(N, sym=True)

# La transformamos en columna para multiplicarla por la matriz de 200 realizaciones
ventana_bh_col = ventana_bh.reshape(N, 1)

# Aplicamos la ventana a la señal en el tiempo
x_r_bh = x_r * ventana_bh_col

# Calculamos la FFT de la señal ventaneada
XXr_bh = np.fft.fft(x_r_bh, n=N, axis=0)

# --- 2. ESTIMADOR DE AMPLITUD (CON BLACKMAN-HARRIS) ---

# Extraemos el bin exacto de w0 (250)

#sesgo

X_w0_bh = XXr_bh[bin_w0, :]

# Escalamos usando la suma de los valores de la ventana Blackman-Harris

a_estimado_bh = (np.abs(X_w0_bh)*2) / N

E_a_bh = np.mean(a_estimado_bh)
sesgo_a_bh = E_a_bh - a0

#varianza

varianza_a_bh = np.var(a_estimado_bh)

# --- 3. ESTIMADOR DE FRECUENCIA (CON BLACKMAN-HARRIS) ---

# Nos quedamos con la mitad del espectro
magnitud_espectro_bh = np.abs(XXr_bh[:N//2 + 1, :])

# Buscamos el bin con mayor energía
f_estimado_bh = np.argmax(magnitud_espectro_bh, axis=0)


E_k_bh = np.mean(f_estimado_bh)
sesgo_k_bh = E_k_bh - w0

#varianza

varianza_k_bh = np.var(f_estimado_bh)

#HAMMING

# M=N, sym=True es el comportamiento por defecto
ventana_hm = hamming(N, sym=True)

# La transformamos en columna
ventana_hm_col = ventana_hm.reshape(N, 1)

# Aplicamos la ventana a la señal en el tiempo
x_r_hm = x_r * ventana_hm_col

# Calculamos la FFT de la señal ventaneada
XXr_hm = np.fft.fft(x_r_hm, n=N, axis=0)

# --- 2. ESTIMADOR DE AMPLITUD (CON HAMMING) ---

#sesgo

# Extraemos el bin exacto de w0 (250)
X_w0_hm = XXr_hm[bin_w0, :]

# Escalamos usando la suma de los valores de la ventana Hamming

a_estimado_hm = (np.abs(X_w0_hm) * 2) / N


E_a_hm = np.mean(a_estimado_hm)
sesgo_a_hm = E_a_hm - a0

#varianza

varianza_a_hm = np.var(a_estimado_hm)

# --- 3. ESTIMADOR DE FRECUENCIA (CON HAMMING) ---

#sesgo

# Nos quedamos con la mitad del espectro
magnitud_espectro_hm = np.abs(XXr_hm[:N//2 + 1, :])

# Buscamos el bin con mayor energía
f_estimado_hm = np.argmax(magnitud_espectro_hm, axis=0)

# Cálculos estadísticos
E_f_hm = np.mean(f_estimado_hm)
sesgo_f_hm = E_f_hm - w0

#varianza
varianza_f_hm = np.var(f_estimado_hm)

#%% -------------- HISTOGRAMAS ------------------

fig, axes = plt.subplots(2, 4, figsize=(18, 8))
fig.suptitle(f'Histogramas de Estimadores — SNR = {SNR_dB} dB', fontsize=14, fontweight='bold')

# --- Datos organizados ---
ventanas       = ['Rectangular', 'Flat Top', 'Blackman-Harris', 'Hamming']
estimados_amp  = [a_r_estimado, a_estimado_ft, a_estimado_bh, a_estimado_hm]
estimados_freq = [f_r_estimado, f_estimado_ft, f_estimado_bh, f_estimado_hm]

colores = ['steelblue', 'darkorange', 'forestgreen', 'crimson']

for i, (ventana, amp, freq, color) in enumerate(zip(ventanas, estimados_amp, estimados_freq, colores)):

    # --- Fila 0: Amplitud ---
    ax_a = axes[0, i]
    ax_a.hist(amp, bins=20, color=color, edgecolor='black', alpha=0.85)
    ax_a.axvline(a0, color='black', linestyle='--', linewidth=1.5, label=f'a₀ = {a0:.3f}')
    ax_a.axvline(np.mean(amp), color='red', linestyle='-', linewidth=1.5, label=f'E[â] = {np.mean(amp):.3f}')
    ax_a.set_title(f'{ventana}', fontsize=11)
    ax_a.set_xlabel('Amplitud estimada')
    ax_a.set_ylabel('Frecuencia' if i == 0 else '')
    ax_a.legend(fontsize=7)

    # --- Fila 1: Frecuencia ---
    ax_f = axes[1, i]
    ax_f.hist(freq, bins=20, color=color, edgecolor='black', alpha=0.85)
    ax_f.axvline(w0, color='black', linestyle='--', linewidth=1.5, label=f'w₀ = {w0}')
    ax_f.axvline(np.mean(freq), color='red', linestyle='-', linewidth=1.5, label=f'E[ŵ] = {np.mean(freq):.2f}')
    ax_f.set_xlabel('Bin de frecuencia estimado')
    ax_f.set_ylabel('Frecuencia' if i == 0 else '')
    ax_f.legend(fontsize=7)

# Etiquetas de fila a la izquierda
axes[0, 0].set_ylabel('Amplitud\nFrecuencia relativa', fontsize=10)
axes[1, 0].set_ylabel('Frecuencia\nFrecuencia relativa', fontsize=10)

plt.tight_layout()
plt.show()

#%% -------------- HISTOGRAMAS SUPERPUESTOS ------------------

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle(f'Histogramas de Estimadores — SNR = {SNR_dB} dB', fontsize=13, fontweight='bold')

ventanas       = ['Rectangular', 'Flat Top', 'Blackman-Harris', 'Hamming']
estimados_amp  = [a_r_estimado, a_estimado_ft, a_estimado_bh, a_estimado_hm]
estimados_freq = [f_r_estimado, f_estimado_ft, f_estimado_bh, f_estimado_hm]
colores        = ['steelblue', 'darkorange', 'forestgreen', 'crimson']

# --- Histograma de Amplitud ---
ax = axes[0]
for amp, ventana, color in zip(estimados_amp, ventanas, colores):
    ax.hist(amp, bins=20, alpha=0.5, color=color, edgecolor='black', linewidth=0.5, label=ventana)
ax.axvline(a0, color='black', linestyle='--', linewidth=2, label=f'a₀ real = {a0:.3f}')
ax.set_title('Estimador de Amplitud')
ax.set_xlabel('Amplitud estimada')
ax.set_ylabel('Frecuencia relativa')
ax.legend()

# --- Histograma de Frecuencia ---
ax = axes[1]
for freq, ventana, color in zip(estimados_freq, ventanas, colores):
    ax.hist(freq, bins=20, alpha=0.5, color=color, edgecolor='black', linewidth=0.5, label=ventana)
ax.axvline(w0, color='black', linestyle='--', linewidth=2, label=f'w₀ real = {w0}')
ax.set_title('Estimador de Frecuencia')
ax.set_xlabel('Bin de frecuencia estimado')
ax.set_ylabel('Frecuencia relativa')
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Histogramas de estimadores a 3 dB

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal.windows import flattop
from scipy.signal.windows import blackmanharris
from scipy.signal.windows import hamming

#DECLARACION DE VARIABLES 

N = 1000 #Cantidad de muestras (filas)
R = 200 #cantidad de realizaciones (Columna)
w0 = N/4 #frecuencia de w0 en mitad de nyquist
a0 = np.sqrt(2) #amplitud, elijo raiz(2) para normalizarla
Ps = 1
mu = 0
SNR_dB = 3  # es el SNR deseado, ej 10
Pr = Ps / (10**(SNR_dB/10)) #potencia del ruido 

#genero una lista de valores random de -2 a 2

fr = np.random.uniform(low=-2, high=2,size =  200) 

#genero el vector de n de 1000 elementos

n = np.arange(N) #Genero de un array de muestras con una cantidad de N-1 muestras
array_n = n.reshape(N,1)
#frecuencia

w = (2 * np.pi/N) * (w0 + fr)
 
#%% CREO SENO CON RUIDO

SNR_dB = 10  # es el SNR deseado, ej 10
Pr = Ps / (10**(SNR_dB/10)) #potencia del ruido 

#ruido
sigma = np.sqrt(Pr) #es la que uso en ruido, sigma² es potencia de ruido
ruido = np.random.normal(mu, sigma, size = (N,R))

#Funcion seno

x_n= a0*np.sin((w*array_n)) 

#Le sumo el ruido

x_r =  x_n + ruido

#PSD y graficos
XXr = np.fft.fft(x_r,n=N, axis = 0)
#%% -------------- VENTANEO ------------------

#RECTANGULAR

#Estimador de Energia

#Sesgo

# 1. Identificamos el bin exacto de nuestra frecuencia fundamental w0
bin_w0 = int(N/4) # Esto da 250, sino daria 250.0

# 2. Extraemos el valor complejo de la FFT en ese bin para las 200 realizaciones
# XXr tiene forma (1000, 200), así que tomamos la fila 250 y todas las columnas (:)
X_w0 = XXr[bin_w0, :]  #el resultado es una vector de 200 numeros

#cada elemento de X_w0 es la FFT de en w0 de cada experimento

# 3. Calculamos la amplitud estimada para cada una de las 200 realizaciones

a_r_estimado = (np.abs(X_w0) * 2) / N #multiplico por 2 para recuperar la energia dividida en dos mitades
                                    # divido por N para escalar bien
# 4. Calculamos el valor esperado (promedio de las 200 estimaciones)
E_a = np.mean(a_r_estimado)

# 5. Calculamos el sesgo
sesgo = E_a - a0

#Varianza

varianza_a = np.var(a_r_estimado)

#Estimador de Frecuencia

# Sesgo

# 1. Nos quedamos con la magnitud de la mitad positiva del espectro (Nyquist)
# para asegurarnos de no agarrar el pico de las frecuencias negativas por error.
magnitud_espectro = np.abs(XXr[:N//2 + 1, :])

# 2. Encontramos el índice (el bin 'k') donde está el máximo de energía
f_r_estimado = np.argmax(magnitud_espectro, axis=0)
# k_estimado es ahora un vector de 200 números (ej: [249, 251, 250, 248...])

# 3. Calculamos el valor esperado (promedio de los 200 índices estimados)
E_f_r = np.mean(f_r_estimado)

# 4. Calculamos el sesgo (Diferencia entre el promedio estimado y la frecuencia real w0)
sesgo_f_r = E_f_r - w0

# Varianza
varianza_f_r = np.var(f_r_estimado)

#FLATTOP
ventana_ft = flattop(N, sym=True)

ventana_ft_col = ventana_ft.reshape(N, 1)

# Aplicamos el ventaneo multiplicando la señal por la ventana en el tiempo
x_r_ft = x_r * ventana_ft_col

# Calculamos la nueva FFT sobre la señal ventaneada
XXr_ft = np.fft.fft(x_r_ft, n=N, axis=0)
# ---  ESTIMADOR DE AMPLITUD (CON FLAT TOP) ---

#sesgo

# Extraemos el bin de interés
X_w0_ft = XXr_ft[bin_w0, :]

a_estimado_ft = (np.abs(X_w0_ft)*2) / N

#a_estimado_ft = (np.abs(X_w0_ft)) / N #Lo dividimos por la suma de los valores de la ventana

E_a_ft = np.mean(a_estimado_ft)
sesgo_a_ft = E_a_ft - a0

#varianza
varianza_a_ft = np.var(a_estimado_ft)

# ---  ESTIMADOR DE FRECUENCIA (CON FLAT TOP) ---

#sesgo

magnitud_espectro_ft = np.abs(XXr_ft[:N//2 + 1, :])
f_estimado_ft = np.argmax(magnitud_espectro_ft, axis=0)


E_k_ft = np.mean(f_estimado_ft)
sesgo_k_ft = E_k_ft - w0

#varianza

varianza_k_ft = np.var(f_estimado_ft)

#BLACHMANHARRIS


# Generamos la ventana de tamaño N (1000 muestras)
ventana_bh = blackmanharris(N, sym=True)

# La transformamos en columna para multiplicarla por la matriz de 200 realizaciones
ventana_bh_col = ventana_bh.reshape(N, 1)

# Aplicamos la ventana a la señal en el tiempo
x_r_bh = x_r * ventana_bh_col

# Calculamos la FFT de la señal ventaneada
XXr_bh = np.fft.fft(x_r_bh, n=N, axis=0)

# --- 2. ESTIMADOR DE AMPLITUD (CON BLACKMAN-HARRIS) ---

# Extraemos el bin exacto de w0 (250)

#sesgo

X_w0_bh = XXr_bh[bin_w0, :]

# Escalamos usando la suma de los valores de la ventana Blackman-Harris

a_estimado_bh = (np.abs(X_w0_bh)*2) / N

E_a_bh = np.mean(a_estimado_bh)
sesgo_a_bh = E_a_bh - a0

#varianza

varianza_a_bh = np.var(a_estimado_bh)

# --- 3. ESTIMADOR DE FRECUENCIA (CON BLACKMAN-HARRIS) ---

# Nos quedamos con la mitad del espectro
magnitud_espectro_bh = np.abs(XXr_bh[:N//2 + 1, :])

# Buscamos el bin con mayor energía
f_estimado_bh = np.argmax(magnitud_espectro_bh, axis=0)


E_k_bh = np.mean(f_estimado_bh)
sesgo_k_bh = E_k_bh - w0

#varianza

varianza_k_bh = np.var(f_estimado_bh)

#HAMMING

# M=N, sym=True es el comportamiento por defecto
ventana_hm = hamming(N, sym=True)

# La transformamos en columna
ventana_hm_col = ventana_hm.reshape(N, 1)

# Aplicamos la ventana a la señal en el tiempo
x_r_hm = x_r * ventana_hm_col

# Calculamos la FFT de la señal ventaneada
XXr_hm = np.fft.fft(x_r_hm, n=N, axis=0)

# --- 2. ESTIMADOR DE AMPLITUD (CON HAMMING) ---

#sesgo

# Extraemos el bin exacto de w0 (250)
X_w0_hm = XXr_hm[bin_w0, :]

# Escalamos usando la suma de los valores de la ventana Hamming

a_estimado_hm = (np.abs(X_w0_hm) * 2) / N


E_a_hm = np.mean(a_estimado_hm)
sesgo_a_hm = E_a_hm - a0

#varianza

varianza_a_hm = np.var(a_estimado_hm)

# --- 3. ESTIMADOR DE FRECUENCIA (CON HAMMING) ---

#sesgo

# Nos quedamos con la mitad del espectro
magnitud_espectro_hm = np.abs(XXr_hm[:N//2 + 1, :])

# Buscamos el bin con mayor energía
f_estimado_hm = np.argmax(magnitud_espectro_hm, axis=0)

# Cálculos estadísticos
E_f_hm = np.mean(f_estimado_hm)
sesgo_f_hm = E_f_hm - w0

#varianza
varianza_f_hm = np.var(f_estimado_hm)

#%% -------------- HISTOGRAMAS ------------------

fig, axes = plt.subplots(2, 4, figsize=(18, 8))
fig.suptitle(f'Histogramas de Estimadores — SNR = {SNR_dB} dB', fontsize=14, fontweight='bold')

# --- Datos organizados ---
ventanas       = ['Rectangular', 'Flat Top', 'Blackman-Harris', 'Hamming']
estimados_amp  = [a_r_estimado, a_estimado_ft, a_estimado_bh, a_estimado_hm]
estimados_freq = [f_r_estimado, f_estimado_ft, f_estimado_bh, f_estimado_hm]

colores = ['steelblue', 'darkorange', 'forestgreen', 'crimson']

for i, (ventana, amp, freq, color) in enumerate(zip(ventanas, estimados_amp, estimados_freq, colores)):

    # --- Fila 0: Amplitud ---
    ax_a = axes[0, i]
    ax_a.hist(amp, bins=20, color=color, edgecolor='black', alpha=0.85)
    ax_a.axvline(a0, color='black', linestyle='--', linewidth=1.5, label=f'a₀ = {a0:.3f}')
    ax_a.axvline(np.mean(amp), color='red', linestyle='-', linewidth=1.5, label=f'E[â] = {np.mean(amp):.3f}')
    ax_a.set_title(f'{ventana}', fontsize=11)
    ax_a.set_xlabel('Amplitud estimada')
    ax_a.set_ylabel('Frecuencia' if i == 0 else '')
    ax_a.legend(fontsize=7)

    # --- Fila 1: Frecuencia ---
    ax_f = axes[1, i]
    ax_f.hist(freq, bins=20, color=color, edgecolor='black', alpha=0.85)
    ax_f.axvline(w0, color='black', linestyle='--', linewidth=1.5, label=f'w₀ = {w0}')
    ax_f.axvline(np.mean(freq), color='red', linestyle='-', linewidth=1.5, label=f'E[ŵ] = {np.mean(freq):.2f}')
    ax_f.set_xlabel('Bin de frecuencia estimado')
    ax_f.set_ylabel('Frecuencia' if i == 0 else '')
    ax_f.legend(fontsize=7)

# Etiquetas de fila a la izquierda
axes[0, 0].set_ylabel('Amplitud\nFrecuencia relativa', fontsize=10)
axes[1, 0].set_ylabel('Frecuencia\nFrecuencia relativa', fontsize=10)

plt.tight_layout()
plt.show()

#%% -------------- HISTOGRAMAS SUPERPUESTOS ------------------

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle(f'Histogramas de Estimadores — SNR = {SNR_dB} dB', fontsize=13, fontweight='bold')

ventanas       = ['Rectangular', 'Flat Top', 'Blackman-Harris', 'Hamming']
estimados_amp  = [a_r_estimado, a_estimado_ft, a_estimado_bh, a_estimado_hm]
estimados_freq = [f_r_estimado, f_estimado_ft, f_estimado_bh, f_estimado_hm]
colores        = ['steelblue', 'darkorange', 'forestgreen', 'crimson']

# --- Histograma de Amplitud ---
ax = axes[0]
for amp, ventana, color in zip(estimados_amp, ventanas, colores):
    ax.hist(amp, bins=20, alpha=0.5, color=color, edgecolor='black', linewidth=0.5, label=ventana)
ax.axvline(a0, color='black', linestyle='--', linewidth=2, label=f'a₀ real = {a0:.3f}')
ax.set_title('Estimador de Amplitud')
ax.set_xlabel('Amplitud estimada')
ax.set_ylabel('Frecuencia relativa')
ax.legend()

# --- Histograma de Frecuencia ---
ax = axes[1]
for freq, ventana, color in zip(estimados_freq, ventanas, colores):
    ax.hist(freq, bins=20, alpha=0.5, color=color, edgecolor='black', linewidth=0.5, label=ventana)
ax.axvline(w0, color='black', linestyle='--', linewidth=2, label=f'w₀ real = {w0}')
ax.set_title('Estimador de Frecuencia')
ax.set_xlabel('Bin de frecuencia estimado')
ax.set_ylabel('Frecuencia relativa')
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# A través de los histogramas, se logra validar visualmente el comportamiento estadístico detallado en las tablas de los estimadores para los escenarios de 3 dB y 10 dB. para el caso de los estimadores de amplitud, es evidente que la ventana Rectangular presenta la mayor dispersión (varianza), con valores de amplitud que se distribuyen en un rango muy amplio. Esto se debe a cuando la frecuencia no es síncrona con los bins de la FFT. Por el contrario, la ventana Flat-Top muestra una distribución notablemente estrecha y concentrada. Esta baja varianza gráfica demuestra su eficacia para mantener una lectura de amplitud estable, independientemente del desplazamiento de la frecuencia fundamental ($\pm 2$ bins).Los histogramas de frecuencia presentan un comportamiento consistente con el diseño del experimento. Las estimaciones se agrupan en el rango de [248, 252], lo cual es coherente con una frecuencia central $w_0 = 250$ afectada por una distribución uniforme de desviación $fr \in [-2, 2]$. La naturaleza "discreta" (en forma de barras separadas) de estos histogramas refleja el límite de resolución del estimador basado en el bin de máxima energía (argmax), el cual está restringido a valores enteros de $k$.

# %% [markdown]
# ## Bonus 2)

# %% [markdown]
# Para esta experiencia voy a analizar el efecto de zero-padding para el estimador de frecuencia cuando aplicamos una ventana rectangular. Voy a analizarlo para el caso donde tenemos un SNR de 10 dB.

# %%
N = 1000
R = 200
w0 = N/4
a0 = np.sqrt(2)
Ps = 1
SNR_dB = 10
Pr = Ps / (10**(SNR_dB/10))
sigma = np.sqrt(Pr)

# Generamos frecuencia aleatoria
fr = np.random.uniform(low=-2, high=2, size=200)
n = np.arange(N).reshape(N, 1)
w = (2 * np.pi/N) * (w0 + fr)

# Señal con ruido
ruido = np.random.normal(0, sigma, size=(N, R))
x_n = a0 * np.sin(w * n)
x_r = x_n + ruido

# --- VENTANEO RECTANGULAR ---
# No multiplicamos por nada, o usamos una ventana de unos
ventana_rect = np.ones((N, 1))
x_v_rect = x_r * ventana_rect

# --- 1. FFT SIN ZERO-PADDING ---
XX_normal = np.fft.fft(x_v_rect, n=N, axis=0)
mag_normal = np.abs(XX_normal[:N//2 + 1, :])
f_est_normal = np.argmax(mag_normal, axis=0)

# --- 2. FFT CON ZERO-PADDING (Factor 10) ---
N_pad = 10 * N 
XX_zp = np.fft.fft(x_v_rect, n=N_pad, axis=0)
mag_zp = np.abs(XX_zp[:N_pad//2 + 1, :])
f_est_zp = np.argmax(mag_zp, axis=0) / 10

# --- ESTADÍSTICAS CORREGIDAS ---

# Calculamos el error de cada realización (Estimado - Real)
# Frecuencia real de cada columna i es: w0 + fr[i]
f_real_cada_una = w0 + fr

error_normal = f_est_normal - f_real_cada_una
error_zp = f_est_zp - f_real_cada_una

# Ahora la varianza del ERROR es la que muestra la precisión del método
var_error_normal = np.var(error_normal)
var_error_zp = np.var(error_zp)
mejora_real = var_error_normal / var_error_zp

print(f"--- Análisis de Precisión (SNR: {SNR_dB} dB) ---")
print(f"Varianza del ERROR sin ZP: {var_error_normal:.6f}")
print(f"Varianza del ERROR con ZP: {var_error_zp:.6f}")
print(f"Mejora real del algoritmo: {mejora_real:.2f} veces")

# --- COMPARACIÓN DE HISTOGRAMAS DEL ERROR ---

plt.figure(figsize=(12, 5))

# Histograma Sin Zero-Padding
plt.subplot(1, 2, 1)
plt.hist(error_normal, bins=30, color='steelblue', edgecolor='black', alpha=0.7)
plt.axvline(0, color='red', linestyle='--', label='Error cero')
plt.title(f'Error de Frecuencia SIN ZP\nVar: {var_error_normal:.4f}')
plt.xlabel('Error (bins)')
plt.ylabel('Cantidad de casos')
plt.xlim([-1, 1]) # Centramos la vista
plt.legend()

# Histograma Con Zero-Padding
plt.subplot(1, 2, 2)
plt.hist(error_zp, bins=30, color='darkorange', edgecolor='black', alpha=0.7)
plt.axvline(0, color='red', linestyle='--', label='Error cero')
plt.title(f'Error de Frecuencia CON ZP (x10)\nVar: {var_error_zp:.4f}')
plt.xlabel('Error (bins)')
plt.xlim([-1, 1]) # Usamos la misma escala para que se note la diferencia
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# --- Análisis de Precisión (SNR: 10 dB) ---
# Varianza del ERROR sin ZP: 0.080139
# Varianza del ERROR con ZP: 0.000831
# Mejora real del algoritmo: 96.43 veces

# %% [markdown]
# Al analizar la varianza del error de estimación (restando la frecuencia real en cada realización), se observa una mejora drástica al aplicar Zero-Padding con un factor de 10. Mientras que el estimador estándar está limitado por la varianza de cuantización teórica ($1/12 \approx 0.083$), el Zero-Padding interpola el lóbulo principal de la ventana rectangular, permitiendo localizar el máximo con una precisión que ya no depende de la grilla de la FFT, sino de la relación señal-ruido del sistema.

# %% [markdown]
# Comparando los histogramas del error de estimación podemos visualizar la reducción de la incertidumbre. Mientras que el estimador sin Zero-Padding presenta un error distribuido ampliamente debido a la baja resolución de la grilla de la FFT, el estimador con Zero-Padding concentra casi la totalidad de las realizaciones en un entorno alrededor del error cero. Esto demuestra que la técnica no solo mejora la resolución visual, sino que efectivamente incrementa la precisión estadística del proceso de medición de frecuencia.
